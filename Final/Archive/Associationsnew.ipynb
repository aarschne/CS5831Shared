# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, classification_report, confusion_matrix, precision_score
import numpy as np
from sklearn.base import clone

# %%
df = pd.read_csv('../data/foods_health_scores_allergens.csv')
df
# Out:
#                                            product_name           brands  \
# 0                                              Sidi Ali         سيدي علي
# 1                                                 Perly            Perly
# 2                                              Sidi Ali         Sidi Ali
# 3                                Eau minérale naturelle         sidi ali
# 4                                              اكوافينا         AQUAFINA
# ...                                                 ...              ...
# 4992                        Crème fraîche gastronomique        Président
# 4993                    Noix de cajou grillées sans sel  Maître Prunille
# 4994                     Cacao puro en polvo desgrasado            Valor
# 4995                     Sablés Myrtilles Germes de riz           Gerblé
# 4996  Céréales Extra Pepites Kellogg's Chocolat au lait        Kellogg's
#
#                                              categories  \
# 0     en:beverages-and-beverages-preparations, en:be...
# 1     en:dairies, en:fermented-foods, en:fermented-m...
# 2     en:beverages-and-beverages-preparations, en:be...
# 3     en:beverages-and-beverages-preparations, en:be...
# 4     en:beverages-and-beverages-preparations, en:be...
# ...                                                 ...
# 4992  en:dairies, en:fermented-foods, en:fermented-m...
# 4993  en:plant-based-foods-and-beverages, en:plant-b...
# 4994  en:cocoa-and-its-products, en:cocoa-and-chocol...
# 4995  en:snacks, en:sweet-snacks, en:biscuits-and-cakes
# 4996  en:plant-based-foods-and-beverages, en:plant-b...
#
#                                             ingredients nutriscore_grade  \
# 0                     OBD1 999 999 1112606 266963207 mb                A
# 1            milk cream, cream, sugar, banana, bacteria          UNKNOWN
# 2     Sodium, Calcium, Magnésium, Potassium, Bicarbo...                A
# 3                                    100% mineral water                A
# 4     ouverture et avant le : Voir bouteille. après ...                A
# ...                                                 ...              ...
# 4992     _Crème_ (origine France), _ferments lactiques_                D
# 4993                                      Noix de cajou                B
# 4994  Cacao desgrasado en polvo, correctores de acid...                C
# 4995  Farine de blé 58,2%, huile de colza, sucre de ...                A
# 4996  Flocons d'AVOINE(47%), Sucre, Huile de palme, ...                E
#
#       nova_group  ecoscore_grade                        allergens  \
# 0            NaN  NOT-APPLICABLE                              NaN
# 1            3.0               B               en:banana, en:milk
# 2            1.0  NOT-APPLICABLE                              NaN
# 3            1.0  NOT-APPLICABLE                              NaN
# 4            NaN  NOT-APPLICABLE                              NaN
# ...          ...             ...                              ...
# 4992         3.0               A                          en:milk
# 4993         1.0               E                          en:nuts
# 4994         1.0               F                              NaN
# 4995         4.0               C               en:gluten, en:milk
# 4996         4.0               E  en:gluten, en:milk, en:soybeans
#
#       energy_kcal  fat_100g  ...  proteins_100g  salt_100g  sodium_100g  \
# 0             0.0       0.0  ...            0.0   0.000000     0.000000
# 1            97.0       3.0  ...            8.0        NaN          NaN
# 2             NaN       NaN  ...            NaN   0.065000     0.026000
# 3             NaN       NaN  ...            NaN   0.065000     0.026000
# 4             0.0       0.0  ...            0.0   0.000508     0.000203
# ...           ...       ...  ...            ...        ...          ...
# 4992        291.0      30.0  ...            2.3   0.070000     0.028000
# 4993        621.0      47.0  ...           21.0   0.020000     0.008000
# 4994        375.0      16.0  ...           26.0   0.030000     0.012000
# 4995         54.0       2.0  ...            0.9   0.050000     0.020000
# 4996        484.0      22.0  ...            7.0   0.680000     0.272000
#
#       contains_gluten  contains_dairy  contains_nuts  contains_soy  \
# 0               False           False          False         False
# 1               False            True          False         False
# 2               False           False          False         False
# 3               False           False          False         False
# 4               False           False          False         False
# ...               ...             ...            ...           ...
# 4992            False            True          False         False
# 4993            False           False           True         False
# 4994            False           False          False         False
# 4995             True            True          False         False
# 4996             True            True          False          True
#
#       contains_eggs  contains_fish         food_type
# 0             False          False  Branded/Packaged
# 1             False          False  Branded/Packaged
# 2             False          False  Branded/Packaged
# 3             False          False  Branded/Packaged
# 4             False          False  Branded/Packaged
# ...             ...            ...               ...
# 4992          False          False  Branded/Packaged
# 4993          False          False  Branded/Packaged
# 4994          False          False  Branded/Packaged
# 4995          False          False  Branded/Packaged
# 4996          False          False  Branded/Packaged
#
# [4997 rows x 24 columns]

# %%
df["food_type"].value_counts()
# Out:
# food_type
# Branded/Packaged    4997
# Name: count, dtype: int64

# %%
df = df.drop(['product_name', 'brands', 'categories', 'ingredients', 'allergens', 'food_type'], axis = 1)

# %%
binary_contains_cols = [
    'contains_gluten',
    'contains_dairy',
    'contains_nuts',
    'contains_soy',
    'contains_eggs',
    'contains_fish'
]

# %% [markdown]
# ## Model Pipeline Definition

# %%
# show numeric and categorical columns
num_cols = ['energy_kcal','fat_100g', 'saturated_fat_100g', 'carbs_100g', 'sugars_100g','fiber_100g', 'proteins_100g', 'salt_100g', 'sodium_100g']     
cat_cols = ['nutriscore_grade', 'nova_group', 'ecoscore_grade']     

# pipeline for numeric
num_pipeline = Pipeline([
    ("imputer", KNNImputer(n_neighbors=5)),
    ("scaler", StandardScaler())
])

# pipeline for categorical
cat_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

# %% [markdown]
# ## Function Definitions

# %%
# Define thresholds
thresholds = np.arange(0.05, 0.96, 0.05)

# Drop unnecessary columns and perform train-test-validation split
def process(df, y_col: str, cols):
    y = df[y_col].astype(int)
    X = df.drop(columns=[y_col], axis=1)

    X_trainval, X_test, y_trainval, y_test = train_test_split(
        X, y,
        test_size=0.2,
        random_state=5831,
        stratify=y
    )

    X_train, X_val, y_train, y_val = train_test_split(
        X_trainval, y_trainval,
        test_size=0.25,
        random_state=5831,
        stratify=y_trainval
    )

    return X_train, X_val, X_test, y_train, y_val, y_test

# Get recalls for each threshold
def get_recalls(thresholds, y_prob, y_val):
    recalls = dict()
    for t in thresholds:
        y_pred = (y_prob >= t).astype(int)
        if precision_score(y_val, y_pred, pos_label=1) > 0.5:
            recalls[t] = recall_score(y_val, y_pred, pos_label = 1)
        
    max_key = max(recalls, key=recalls.get)
    return recalls, max_key

# Evaluate on the test set
def evaluate_on_test_set(pipe, X_test, y_test, max_key):
    y_prob = pipe.predict_proba(X_test)[:, 1]
    y_pred = (y_prob >= max_key)
    
    recall = recall_score(y_test, y_pred, pos_label=1)
    precision = precision_score(y_test, y_pred, pos_label=1)
    
    cm = confusion_matrix(y_test, y_pred)

    cm_df = pd.DataFrame(
        cm,
        index=["Actual 0", "Actual 1"],
        columns=["Pred 0", "Pred 1"]
    )

    return precision, recall, cm_df

# Get the DataFrame of model coefficients
def get_coef_df(pipe):
    feature_names = pipe.named_steps["preprocess"].get_feature_names_out()
    coefs = pipe.named_steps["lda"].coef_[0]

    coef_df = pd.DataFrame({
        "feature": feature_names,
        "coefficient": coefs,
        "abs_coefficient": np.abs(coefs)
    }).sort_values("abs_coefficient", ascending=False)

    return coef_df

def make_pipe(y_col):
    binary_contains_cols_temp = [c for c in binary_contains_cols if c != y_col]

    preprocess = ColumnTransformer([
        ("num", num_pipeline, num_cols),
        ("cat", cat_pipeline, cat_cols),
        ("bin", "passthrough", binary_contains_cols_temp)
    ])

    pipe = Pipeline([
        ("preprocess", preprocess),
        ("lda", LinearDiscriminantAnalysis())
    ])
    return pipe

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Gluten

# %%
gluten_X_train, gluten_X_val, gluten_X_test, gluten_y_train, gluten_y_val, gluten_y_test = process(df, 'contains_gluten', binary_contains_cols)

baseline_recall_gluten = (gluten_y_test == 1).mean()
print("Baseline recall for gluten:", baseline_recall_gluten)
# Out:
# Baseline recall for gluten: 0.32

# %%
pipe = make_pipe("contains_gluten")
pipe.fit(gluten_X_train, gluten_y_train)
gluten_y_prob = pipe.predict_proba(gluten_X_val)[:, 1]

# %%
gluten_recalls, gluten_max_key = get_recalls(thresholds, gluten_y_prob, gluten_y_val)
print(gluten_max_key)
print(gluten_recalls[gluten_max_key])
# Out:
# 0.1
# 0.96875

# %%
gluten_test_precision, gluten_test_recall, gluten_cm_df = evaluate_on_test_set(pipe, gluten_X_test, gluten_y_test, gluten_max_key)
print("Precision:", gluten_test_precision)
print("Recall:", gluten_test_recall)
# Out:
# Precision: 0.5313588850174216
# Recall: 0.953125

# %%
print(gluten_cm_df)
# Out:
#           Pred 0  Pred 1
# Actual 0     411     269
# Actual 1      15     305

# %%
gluten_coef_df = get_coef_df(pipe)
print(gluten_coef_df)
# Out:
#                                  feature  coefficient  abs_coefficient
# 3                        num__carbs_100g     3.502317         3.502317
# 32                    bin__contains_eggs     2.230773         2.230773
# 1                          num__fat_100g    -2.158506         2.158506
# 0                       num__energy_kcal     1.856911         1.856911
# 4                       num__sugars_100g    -1.730833         1.730833
# 31                     bin__contains_soy     1.574731         1.574731
# 27    cat__ecoscore_grade_NOT-APPLICABLE    -1.406970         1.406970
# 15         cat__nutriscore_grade_UNKNOWN    -1.362527         1.362527
# 14  cat__nutriscore_grade_NOT-APPLICABLE    -1.196443         1.196443
# 16                   cat__nova_group_1.0    -0.855550         0.855550
# 17                   cat__nova_group_2.0     0.731504         0.731504
# 2                num__saturated_fat_100g    -0.716342         0.716342
# 29                   bin__contains_dairy     0.505284         0.505284
# 13               cat__nutriscore_grade_E     0.500997         0.500997
# 5                        num__fiber_100g    -0.425486         0.425486
# 6                     num__proteins_100g    -0.408936         0.408936
# 22                 cat__ecoscore_grade_B     0.331872         0.331872
# 19                   cat__nova_group_4.0     0.280279         0.280279
# 21            cat__ecoscore_grade_A-PLUS    -0.278235         0.278235
# 8                       num__sodium_100g    -0.257532         0.257532
# 7                         num__salt_100g    -0.257490         0.257490
# 11               cat__nutriscore_grade_C     0.254389         0.254389
# 9                cat__nutriscore_grade_A     0.232295         0.232295
# 33                    bin__contains_fish     0.163174         0.163174
# 23                 cat__ecoscore_grade_C     0.124410         0.124410
# 12               cat__nutriscore_grade_D    -0.122470         0.122470
# 30                    bin__contains_nuts     0.109548         0.109548
# 10               cat__nutriscore_grade_B    -0.091271         0.091271
# 26                 cat__ecoscore_grade_F     0.077385         0.077385
# 28           cat__ecoscore_grade_UNKNOWN     0.057681         0.057681
# 18                   cat__nova_group_3.0    -0.055010         0.055010
# 24                 cat__ecoscore_grade_D     0.050159         0.050159
# 25                 cat__ecoscore_grade_E     0.038774         0.038774
# 20                 cat__ecoscore_grade_A    -0.016507         0.016507

# %% [markdown]
# ### Dairy

# %%
dairy_X_train, dairy_X_val, dairy_X_test, dairy_y_train, dairy_y_val, dairy_y_test = process(df, 'contains_dairy', binary_contains_cols)

baseline_recall_dairy = (dairy_y_test == 1).mean()
print("Baseline recall for dairy:", baseline_recall_dairy)
# Out:
# Baseline recall for dairy: 0.299

# %%
pipe = make_pipe("contains_dairy")
pipe.fit(dairy_X_train, dairy_y_train)
dairy_y_prob = pipe.predict_proba(dairy_X_val)[:, 1]

# %%
dairy_recalls, dairy_max_key = get_recalls(thresholds, dairy_y_prob, dairy_y_val)
print(dairy_max_key)
print(dairy_recalls[dairy_max_key])
# Out:
# 0.25
# 0.7785234899328859

# %%
dairy_test_precision, dairy_test_recall, dairy_cm_df = evaluate_on_test_set(pipe, dairy_X_test, dairy_y_test, dairy_max_key)
print("Precision for dairy:", dairy_test_precision)
print("Recall for dairy:", dairy_test_recall)
# Out:
# Precision for dairy: 0.5436893203883495
# Recall for dairy: 0.7491638795986622

# %%
print(dairy_cm_df)
# Out:
#           Pred 0  Pred 1
# Actual 0     513     188
# Actual 1      75     224

# %%
dairy_coef_df = get_coef_df(pipe)
print(dairy_coef_df)
# Out:
#                                  feature  coefficient  abs_coefficient
# 27    cat__ecoscore_grade_NOT-APPLICABLE    -1.787348         1.787348
# 2                num__saturated_fat_100g     1.680299         1.680299
# 32                    bin__contains_eggs     1.568852         1.568852
# 30                    bin__contains_nuts     1.169314         1.169314
# 33                    bin__contains_fish    -1.043554         1.043554
# 3                        num__carbs_100g    -1.024666         1.024666
# 24                 cat__ecoscore_grade_D     0.707998         0.707998
# 29                  bin__contains_gluten     0.694280         0.694280
# 31                     bin__contains_soy     0.676208         0.676208
# 21            cat__ecoscore_grade_A-PLUS    -0.658520         0.658520
# 13               cat__nutriscore_grade_E     0.618529         0.618529
# 23                 cat__ecoscore_grade_C     0.603481         0.603481
# 0                       num__energy_kcal    -0.583357         0.583357
# 9                cat__nutriscore_grade_A    -0.479912         0.479912
# 26                 cat__ecoscore_grade_F    -0.470558         0.470558
# 1                          num__fat_100g    -0.453068         0.453068
# 28           cat__ecoscore_grade_UNKNOWN    -0.421395         0.421395
# 25                 cat__ecoscore_grade_E     0.308741         0.308741
# 15         cat__nutriscore_grade_UNKNOWN    -0.306762         0.306762
# 5                        num__fiber_100g     0.299057         0.299057
# 8                       num__sodium_100g    -0.227449         0.227449
# 7                         num__salt_100g    -0.227428         0.227428
# 6                     num__proteins_100g     0.216802         0.216802
# 4                       num__sugars_100g     0.203527         0.203527
# 16                   cat__nova_group_1.0     0.189803         0.189803
# 10               cat__nutriscore_grade_B    -0.168730         0.168730
# 22                 cat__ecoscore_grade_B     0.154808         0.154808
# 20                 cat__ecoscore_grade_A    -0.138274         0.138274
# 14  cat__nutriscore_grade_NOT-APPLICABLE     0.085210         0.085210
# 12               cat__nutriscore_grade_D     0.081317         0.081317
# 18                   cat__nova_group_3.0    -0.061888         0.061888
# 19                   cat__nova_group_4.0    -0.029342         0.029342
# 17                   cat__nova_group_2.0    -0.028139         0.028139
# 11               cat__nutriscore_grade_C    -0.001374         0.001374

# %% [markdown]
# ### Nuts

# %%
nuts_X_train, nuts_X_val, nuts_X_test, nuts_y_train, nuts_y_val, nuts_y_test = process(df, 'contains_nuts', binary_contains_cols)

baseline_recall_nuts = (nuts_y_test == 1).mean()
print("Baseline recall for nuts:", baseline_recall_nuts)
# Out:
# Baseline recall for nuts: 0.118

# %%
pipe = make_pipe("contains_nuts")
pipe.fit(nuts_X_train, nuts_y_train)
nuts_y_prob = pipe.predict_proba(nuts_X_val)[:, 1]

# %%
nuts_recalls, nuts_max_key = get_recalls(thresholds, nuts_y_prob, nuts_y_val)
print(nuts_max_key)
print(nuts_recalls[nuts_max_key])
# Out:
# 0.45
# 0.4406779661016949

# %%
nuts_test_precision, nuts_test_recall, nuts_cm_df = evaluate_on_test_set(pipe, nuts_X_test, nuts_y_test, nuts_max_key)
print("Precision for nuts:", nuts_test_precision)
print("Recall for nuts:", nuts_test_recall)
# Out:
# Precision for nuts: 0.5789473684210527
# Recall for nuts: 0.559322033898305

# %%
print(nuts_cm_df)
# Out:
#           Pred 0  Pred 1
# Actual 0     834      48
# Actual 1      52      66

# %%
nuts_coef_df = get_coef_df(pipe)
print(nuts_coef_df)
# Out:
#                                  feature  coefficient  abs_coefficient
# 8                       num__sodium_100g   169.255403       169.255403
# 7                         num__salt_100g  -169.218969       169.218969
# 17                   cat__nova_group_2.0    -2.926621         2.926621
# 33                    bin__contains_fish    -2.099953         2.099953
# 4                       num__sugars_100g     1.470599         1.470599
# 1                          num__fat_100g     1.234412         1.234412
# 15         cat__nutriscore_grade_UNKNOWN    -1.107986         1.107986
# 2                num__saturated_fat_100g    -1.076376         1.076376
# 6                     num__proteins_100g     0.811917         0.811917
# 3                        num__carbs_100g    -0.787163         0.787163
# 30                   bin__contains_dairy     0.760651         0.760651
# 31                     bin__contains_soy     0.724441         0.724441
# 0                       num__energy_kcal     0.615542         0.615542
# 14  cat__nutriscore_grade_NOT-APPLICABLE     0.594420         0.594420
# 16                   cat__nova_group_1.0     0.541693         0.541693
# 20                 cat__ecoscore_grade_A    -0.464995         0.464995
# 25                 cat__ecoscore_grade_E     0.412204         0.412204
# 23                 cat__ecoscore_grade_C    -0.378992         0.378992
# 12               cat__nutriscore_grade_D    -0.336775         0.336775
# 29                  bin__contains_gluten     0.333440         0.333440
# 27    cat__ecoscore_grade_NOT-APPLICABLE     0.319346         0.319346
# 11               cat__nutriscore_grade_C     0.314314         0.314314
# 22                 cat__ecoscore_grade_B     0.312734         0.312734
# 10               cat__nutriscore_grade_B     0.310971         0.310971
# 32                    bin__contains_eggs    -0.285354         0.285354
# 21            cat__ecoscore_grade_A-PLUS    -0.239601         0.239601
# 5                        num__fiber_100g     0.223725         0.223725
# 19                   cat__nova_group_4.0     0.208710         0.208710
# 26                 cat__ecoscore_grade_F    -0.194677         0.194677
# 24                 cat__ecoscore_grade_D     0.114051         0.114051
# 13               cat__nutriscore_grade_E     0.112617         0.112617
# 28           cat__ecoscore_grade_UNKNOWN     0.075424         0.075424
# 9                cat__nutriscore_grade_A     0.060676         0.060676
# 18                   cat__nova_group_3.0     0.004799         0.004799

# %% [markdown]
# ### Soy

# %%
soy_X_train, soy_X_val, soy_X_test, soy_y_train, soy_y_val, soy_y_test = process(df, 'contains_soy', binary_contains_cols)

baseline_recall_soy = (soy_y_test == 1).mean()
print("Baseline recall for soy:", baseline_recall_soy)
# Out:
# Baseline recall for soy: 0.17

# %%
pipe = make_pipe("contains_soy")
pipe.fit(soy_X_train, soy_y_train)
soy_y_prob = pipe.predict_proba(soy_X_val)[:, 1]

# %%
soy_recalls, soy_max_key = get_recalls(thresholds, soy_y_prob, soy_y_val)
print(soy_max_key)
print(soy_recalls[soy_max_key])
# Out:
# 0.35000000000000003
# 0.4260355029585799

# %%
soy_test_precision, soy_test_recall, soy_cm_df = evaluate_on_test_set(pipe, soy_X_test, soy_y_test, soy_max_key)
print("Precision for soy:", soy_test_precision)
print("Recall for soy:", soy_test_recall)
# Out:
# Precision for soy: 0.5594405594405595
# Recall for soy: 0.47058823529411764

# %%
print(soy_cm_df)
# Out:
#           Pred 0  Pred 1
# Actual 0     767      63
# Actual 1      90      80

# %%
soy_coef_df = get_coef_df(pipe)
print(soy_coef_df)
# Out:
#                                  feature  coefficient  abs_coefficient
# 17                   cat__nova_group_2.0    -2.320609         2.320609
# 29                  bin__contains_gluten     1.618731         1.618731
# 3                        num__carbs_100g    -1.557116         1.557116
# 4                       num__sugars_100g     1.158755         1.158755
# 21            cat__ecoscore_grade_A-PLUS     1.146800         1.146800
# 30                   bin__contains_dairy     1.042749         1.042749
# 19                   cat__nova_group_4.0     0.787930         0.787930
# 13               cat__nutriscore_grade_E     0.677010         0.677010
# 31                    bin__contains_nuts     0.620506         0.620506
# 26                 cat__ecoscore_grade_F     0.608274         0.608274
# 1                          num__fat_100g     0.565566         0.565566
# 12               cat__nutriscore_grade_D    -0.510890         0.510890
# 25                 cat__ecoscore_grade_E     0.487425         0.487425
# 16                   cat__nova_group_1.0    -0.415158         0.415158
# 10               cat__nutriscore_grade_B     0.375709         0.375709
# 15         cat__nutriscore_grade_UNKNOWN    -0.373643         0.373643
# 22                 cat__ecoscore_grade_B    -0.366332         0.366332
# 11               cat__nutriscore_grade_C    -0.339966         0.339966
# 14  cat__nutriscore_grade_NOT-APPLICABLE     0.287526         0.287526
# 18                   cat__nova_group_3.0    -0.258832         0.258832
# 6                     num__proteins_100g     0.224817         0.224817
# 24                 cat__ecoscore_grade_D    -0.222790         0.222790
# 33                    bin__contains_fish     0.211712         0.211712
# 23                 cat__ecoscore_grade_C    -0.160991         0.160991
# 27    cat__ecoscore_grade_NOT-APPLICABLE    -0.155534         0.155534
# 7                         num__salt_100g     0.151165         0.151165
# 8                       num__sodium_100g     0.151150         0.151150
# 9                cat__nutriscore_grade_A     0.112322         0.112322
# 32                    bin__contains_eggs     0.092639         0.092639
# 20                 cat__ecoscore_grade_A    -0.043314         0.043314
# 5                        num__fiber_100g    -0.038811         0.038811
# 0                       num__energy_kcal     0.023118         0.023118
# 2                num__saturated_fat_100g     0.022472         0.022472
# 28           cat__ecoscore_grade_UNKNOWN     0.010531         0.010531

# %% [markdown]
# ### Eggs

# %%
eggs_X_train, eggs_X_val, eggs_X_test, eggs_y_train, eggs_y_val, eggs_y_test = process(df, 'contains_eggs', binary_contains_cols)

baseline_recall_eggs = (eggs_y_test == 1).mean()
print("Baseline recall for eggs:", baseline_recall_eggs)
# Out:
# Baseline recall for eggs: 0.064

# %%
pipe = make_pipe("contains_eggs")
pipe.fit(eggs_X_train, eggs_y_train)
eggs_y_prob = pipe.predict_proba(eggs_X_val)[:, 1]

# %%
eggs_recalls, eggs_max_key = get_recalls(thresholds, eggs_y_prob, eggs_y_val)
print(eggs_max_key)
print(eggs_recalls[eggs_max_key])
# Out:
# 0.5
# 0.203125
# /home/neh8/anaconda3/envs/dmsp26/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/neh8/anaconda3/envs/dmsp26/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/neh8/anaconda3/envs/dmsp26/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
eggs_test_precision, eggs_test_recall, eggs_cm_df = evaluate_on_test_set(pipe, eggs_X_test, eggs_y_test, eggs_max_key)
print("Precision for eggs:", eggs_test_precision)
print("Recall for eggs:", eggs_test_recall)
# Out:
# Precision for eggs: 0.38095238095238093
# Recall for eggs: 0.25

# %%
print(eggs_cm_df)
# Out:
#           Pred 0  Pred 1
# Actual 0     910      26
# Actual 1      48      16

# %%
eggs_coef_df = get_coef_df(pipe)
print(eggs_coef_df)
# Out:
#                                  feature  coefficient  abs_coefficient
# 33                    bin__contains_fish     2.993628         2.993628
# 29                  bin__contains_gluten     1.980689         1.980689
# 1                          num__fat_100g     1.941003         1.941003
# 2                num__saturated_fat_100g    -1.718673         1.718673
# 30                   bin__contains_dairy     1.531886         1.531886
# 17                   cat__nova_group_2.0    -1.373782         1.373782
# 31                    bin__contains_nuts    -1.167241         1.167241
# 23                 cat__ecoscore_grade_C     1.103367         1.103367
# 25                 cat__ecoscore_grade_E    -0.896815         0.896815
# 10               cat__nutriscore_grade_B    -0.870468         0.870468
# 13               cat__nutriscore_grade_E     0.828885         0.828885
# 26                 cat__ecoscore_grade_F    -0.689383         0.689383
# 14  cat__nutriscore_grade_NOT-APPLICABLE    -0.501959         0.501959
# 6                     num__proteins_100g    -0.472502         0.472502
# 0                       num__energy_kcal    -0.416401         0.416401
# 32                     bin__contains_soy     0.406873         0.406873
# 3                        num__carbs_100g     0.382724         0.382724
# 20                 cat__ecoscore_grade_A    -0.382296         0.382296
# 19                   cat__nova_group_4.0     0.367937         0.367937
# 27    cat__ecoscore_grade_NOT-APPLICABLE    -0.299156         0.299156
# 4                       num__sugars_100g     0.236583         0.236583
# 18                   cat__nova_group_3.0    -0.194233         0.194233
# 15         cat__nutriscore_grade_UNKNOWN    -0.180008         0.180008
# 24                 cat__ecoscore_grade_D     0.179700         0.179700
# 8                       num__sodium_100g     0.176930         0.176930
# 7                         num__salt_100g     0.176910         0.176910
# 12               cat__nutriscore_grade_D     0.158795         0.158795
# 11               cat__nutriscore_grade_C    -0.143316         0.143316
# 22                 cat__ecoscore_grade_B     0.129587         0.129587
# 5                        num__fiber_100g     0.085109         0.085109
# 9                cat__nutriscore_grade_A    -0.047758         0.047758
# 16                   cat__nova_group_1.0    -0.011136         0.011136
# 21            cat__ecoscore_grade_A-PLUS     0.003574         0.003574
# 28           cat__ecoscore_grade_UNKNOWN     0.002948         0.002948

# %% [markdown]
# ### Fish

# %%
fish_X_train, fish_X_val, fish_X_test, fish_y_train, fish_y_val, fish_y_test = process(df, 'contains_fish', binary_contains_cols)

baseline_recall_fish = (fish_y_test == 1).mean()
print("Baseline recall for fish:", baseline_recall_fish)
# Out:
# Baseline recall for fish: 0.022

# %%
pipe = make_pipe("contains_fish")
pipe.fit(fish_X_train, fish_y_train)
fish_y_prob = pipe.predict_proba(fish_X_val)[:, 1]

# %%
fish_recalls, fish_max_key = get_recalls(thresholds, fish_y_prob, fish_y_val)
print(fish_max_key)
print(fish_recalls[fish_max_key])
# Out:
# 0.5
# 0.6086956521739131

# %%
fish_test_precision, fish_test_recall, fish_cm_df = evaluate_on_test_set(pipe, fish_X_test, fish_y_test, fish_max_key)
print("Precision for fish:", fish_test_precision)
print("Recall for fish:", fish_test_recall)
# Out:
# Precision for fish: 0.3333333333333333
# Recall for fish: 0.5454545454545454

# %%
print(fish_cm_df)
# Out:
#           Pred 0  Pred 1
# Actual 0     954      24
# Actual 1      10      12

# %%
fish_coef_df = get_coef_df(pipe)
print(fish_coef_df)
# Out:
#                                  feature  coefficient  abs_coefficient
# 26                 cat__ecoscore_grade_F     5.477522         5.477522
# 25                 cat__ecoscore_grade_E     4.428199         4.428199
# 33                    bin__contains_eggs     3.347275         3.347275
# 21            cat__ecoscore_grade_A-PLUS    -2.232687         2.232687
# 0                       num__energy_kcal    -2.133455         2.133455
# 16                   cat__nova_group_1.0    -2.104309         2.104309
# 14  cat__nutriscore_grade_NOT-APPLICABLE    -1.976868         1.976868
# 17                   cat__nova_group_2.0     1.937517         1.937517
# 29                  bin__contains_gluten     1.855367         1.855367
# 6                     num__proteins_100g     1.745819         1.745819
# 18                   cat__nova_group_3.0     1.678033         1.678033
# 31                    bin__contains_nuts    -1.593197         1.593197
# 20                 cat__ecoscore_grade_A    -1.449320         1.449320
# 1                          num__fat_100g     1.294402         1.294402
# 30                   bin__contains_dairy    -0.891035         0.891035
# 3                        num__carbs_100g    -0.871769         0.871769
# 4                       num__sugars_100g     0.806674         0.806674
# 27    cat__ecoscore_grade_NOT-APPLICABLE    -0.715074         0.715074
# 22                 cat__ecoscore_grade_B    -0.664956         0.664956
# 19                   cat__nova_group_4.0    -0.643079         0.643079
# 2                num__saturated_fat_100g    -0.614552         0.614552
# 10               cat__nutriscore_grade_B     0.593886         0.593886
# 23                 cat__ecoscore_grade_C    -0.510297         0.510297
# 11               cat__nutriscore_grade_C     0.507781         0.507781
# 13               cat__nutriscore_grade_E    -0.394033         0.394033
# 5                        num__fiber_100g     0.300453         0.300453
# 12               cat__nutriscore_grade_D    -0.264911         0.264911
# 32                     bin__contains_soy     0.225150         0.225150
# 15         cat__nutriscore_grade_UNKNOWN    -0.153067         0.153067
# 9                cat__nutriscore_grade_A     0.122127         0.122127
# 24                 cat__ecoscore_grade_D    -0.072386         0.072386
# 28           cat__ecoscore_grade_UNKNOWN    -0.058113         0.058113
# 8                       num__sodium_100g     0.010341         0.010341
# 7                         num__salt_100g     0.010307         0.010307

# %% [markdown]
# We observe that our association analysis model has very low precision and recall for every variable except gluten. This could be partly due to a lack of samples containing the other allergens. We intend to tune our model hyperparameters to obtain sounder results since we are especially concerned about low recall because false negatives are more problematic than false positives when determining whether or not something contains an allergen.
